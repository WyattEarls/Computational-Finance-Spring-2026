# %%
from pylab import plt, mpl
import os
plt.style.use('seaborn-v0_8')
mpl.rcParams['font.family'] = 'serif'
# %matplotlib inline

# %%
import pickle 
import numpy as np
from random import gauss

# %%
a = [gauss(1.5, 2) for i in range(1000000)]

# %%
path = './data/'

# %%
os.makedirs(os.path.dirname(path + 'data.pkl'), exist_ok=True)

# %%
pkl_file = open(path + 'data.pkl', 'wb')

# %%
# %time pickle.dump(a, pkl_file)
# Out:
# CPU times: total: 46.9 ms
# Wall time: 57.6 ms

# %%
pkl_file.close()

# %%
# !dir {path.replace("/", "\\")}
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 4A66-C709
#
#  Directory of C:\Users\wyatt\anaconda_projects\a6d78ae2-3898-4b7b-84be-fb1978404837\data
#
# 02/24/2026  04:31 PM    <DIR>          .
# 02/24/2026  04:46 PM    <DIR>          ..
# 02/24/2026  04:45 PM         9,003,247 data.pkl
#                1 File(s)      9,003,247 bytes
#                2 Dir(s)  318,611,316,736 bytes free

# %%
f = open(path + 'data.pkl', 'rb')
b = pickle.load(f)
f.close()

# %%
a[:3]
# Out:
# [2.9411019457031538, -0.6682065335555296, 2.98039506261103]

# %%
b[:3]
# Out:
# [2.9411019457031538, -0.6682065335555296, 2.98039506261103]

# %%
np.allclose(np.array(a), np.array(b))
# Out:
# True

# %%
pkl_file = open(path + 'data.pkl', 'wb')

# %%
# %time pickle.dump(np.array(a), pkl_file)
# Out:
# CPU times: total: 93.8 ms
# Wall time: 95.2 ms

# %%
# %time pickle.dump(np.array(a)**2, pkl_file)
# Out:
# CPU times: total: 109 ms
# Wall time: 110 ms

# %%
pkl_file.close()

# %%
# !dir {path.replace("/", "\\")}
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 4A66-C709
#
#  Directory of C:\Users\wyatt\anaconda_projects\a6d78ae2-3898-4b7b-84be-fb1978404837\data
#
# 02/24/2026  04:31 PM    <DIR>          .
# 02/24/2026  04:54 PM    <DIR>          ..
# 02/24/2026  04:55 PM        16,000,326 data.pkl
#                1 File(s)     16,000,326 bytes
#                2 Dir(s)  318,597,140,480 bytes free
